# %% [markdown]
# **Importing required packages**

# %%
import json
import gzip
import pandas as pd
import gensim

# %% [markdown]
# **Downloading the dataset from Amazon Snap --> Cell Phones and Accessories**

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Cell_Phones_and_Accessories_5.json.gz
# Out:
# --2022-04-24 12:20:39--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Cell_Phones_and_Accessories_5.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169071325 (161M) [application/octet-stream]
# Saving to: ‘Cell_Phones_and_Accessories_5.json.gz.1’
#
# Cell_Phones_and_Acc 100%[===================>] 161.24M  49.5MB/s    in 3.4s
#
# 2022-04-24 12:20:43 (47.3 MB/s) - ‘Cell_Phones_and_Accessories_5.json.gz.1’ saved [169071325/169071325]

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Electronics.json.gz
# Out:
# --2022-04-24 12:20:47--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Electronics.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3322874357 (3.1G) [application/octet-stream]
# Saving to: ‘Electronics.json.gz’
#
# Electronics.json.gz 100%[===================>]   3.09G  54.6MB/s    in 59s
#
# 2022-04-24 12:21:45 (54.0 MB/s) - ‘Electronics.json.gz’ saved [3322874357/3322874357]

# %% [markdown]
# **Retrieve 1 lakh records and making balanced dataset**

# %%
reviews = []
sentiment = []
p=0
ng=0
emp=0
with gzip.open("/content/Cell_Phones_and_Accessories_5.json.gz") as f:
    for l in f:
      if p==50000 and ng==50000:
        break
      d=json.loads(l.strip())
      r=d.get("reviewText","")
      if r=="":
        emp+=1
        continue
      rating=int(d.get('overall'))
      if rating>=3 and p<50000:
        sentiment.append(1)
        reviews.append(r)
        p+=1
      elif rating<3 and ng<50000:
        sentiment.append(0)
        reviews.append(r)
        ng+=1

print(emp)
dataset={'Review':reviews,'Sentiment':sentiment}
df=pd.DataFrame(dataset)
df['Sentiment'].describe()
# Out:
# 188
# count    100000.000000
# mean          0.500000
# std           0.500003
# min           0.000000
# 25%           0.000000
# 50%           0.500000
# 75%           1.000000
# max           1.000000
# Name: Sentiment, dtype: float64

# %%
print(p,ng)
# Out:
# 50000 50000

# %% [markdown]
# **Extracted reviews**

# %%
df.head()
# Out:
#                                               Review  Sentiment
# 0  Looks even better in person. Be careful to not...          1
# 1  When you don't want to spend a whole lot of ca...          1
# 2  so the case came on time, i love the design. I...          1
# 3  DON'T CARE FOR IT.  GAVE IT AS A GIFT AND THEY...          0
# 4  I liked it because it was cute, but the studs ...          1

# %% [markdown]
# **Removing Stop words**

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords
newreviews=[]
for line in reviews:
  newreviews.append(remove_stopwords(line))
newreviews[:10]

dataset={'Review':newreviews,'Sentiment':sentiment}
newdf=pd.DataFrame(dataset)
newdf.head()
# Out:
#                                               Review  Sentiment
# 0  Looks better person. Be careful drop phone rhi...          1
# 1  When don't want spend lot cash want great deal...          1
# 2  case came time, love design. I'm actually miss...          1
# 3  DON'T CARE FOR IT. GAVE IT AS A GIFT AND THEY ...          0
# 4  I liked cute, studs fall easily protect phone ...          1

# %% [markdown]
# **Tokenization of reviews and simple preprocessing to remove accents and special characters**

# %%
newdf['tokenized']=newdf['Review'].apply(simple_preprocess,deacc=True)
newdf.head()
# Out:
#                                               Review  Sentiment  \
# 0  Looks better person. Be careful drop phone rhi...          1
# 1  When don't want spend lot cash want great deal...          1
# 2  case came time, love design. I'm actually miss...          1
# 3  DON'T CARE FOR IT. GAVE IT AS A GIFT AND THEY ...          0
# 4  I liked cute, studs fall easily protect phone ...          1
#
#                                            tokenized
# 0  [looks, better, person, be, careful, drop, pho...
# 1  [when, don, want, spend, lot, cash, want, grea...
# 2  [case, came, time, love, design, actually, mis...
# 3  [don, care, for, it, gave, it, as, gift, and, ...
# 4  [liked, cute, studs, fall, easily, protect, ph...

# %% [markdown]
# **Stemming the tokens of each reviews**

# %%
from gensim.parsing.porter import PorterStemmer
porter_stemmer = PorterStemmer()
newdf['stemmed']=[[porter_stemmer.stem(word) for word in tokens] for tokens in newdf['tokenized'] ]
newdf.head()
# Out:
#                                               Review  Sentiment  \
# 0  Looks better person. Be careful drop phone rhi...          1
# 1  When don't want spend lot cash want great deal...          1
# 2  case came time, love design. I'm actually miss...          1
# 3  DON'T CARE FOR IT. GAVE IT AS A GIFT AND THEY ...          0
# 4  I liked cute, studs fall easily protect phone ...          1
#
#                                            tokenized  \
# 0  [looks, better, person, be, careful, drop, pho...
# 1  [when, don, want, spend, lot, cash, want, grea...
# 2  [case, came, time, love, design, actually, mis...
# 3  [don, care, for, it, gave, it, as, gift, and, ...
# 4  [liked, cute, studs, fall, easily, protect, ph...
#
#                                              stemmed
# 0  [look, better, person, be, care, drop, phone, ...
# 1  [when, don, want, spend, lot, cash, want, grea...
# 2  [case, came, time, love, design, actual, miss,...
# 3  [don, care, for, it, gave, it, as, gift, and, ...
# 4  [like, cute, stud, fall, easili, protect, phon...

# %% [markdown]
# **Dropping unwanted columns**

# %%
newdf=newdf.drop(columns=["Review","tokenized"],axis=1)
newdf.head()
# Out:
#    Sentiment                                            stemmed
# 0          1  [look, better, person, be, care, drop, phone, ...
# 1          1  [when, don, want, spend, lot, cash, want, grea...
# 2          1  [case, came, time, love, design, actual, miss,...
# 3          0  [don, care, for, it, gave, it, as, gift, and, ...
# 4          1  [like, cute, stud, fall, easili, protect, phon...

# %% [markdown]
# **Define the word2vec model**
#
#
# 1.   Each word with 100 dimensions
# 2.   Window for skip gram is chosen as 3 (3 words before and after current word)
# 3.   Minimum length review = 1
# 4.   No. of threads = 4

# %%
from gensim.models import Word2Vec
dim = 100
window = 3
min_count = 1
workers = 4 #threads
sg = 1 # skip gram model =1
stemmed_tokens = pd.Series(newdf['stemmed']).values
print(stemmed_tokens)
# Out:
# [list(['look', 'better', 'person', 'be', 'care', 'drop', 'phone', 'rhineston', 'fall', 'duh', 'more', 'decor', 'case', 'protect', 'fit', 'perfectli', 'secur', 'phone', 'overal', 'pleas', 'purchas'])
#  list(['when', 'don', 'want', 'spend', 'lot', 'cash', 'want', 'great', 'deal', 'thi', 'shop', 'bui', 'from'])
#  list(['case', 'came', 'time', 'love', 'design', 'actual', 'miss', 'stud', 'notic', 'stud', 'bit', 'sloppi', 'bow', 'notic', 'haven', 'phone', 've', 'notic', 'far'])
#  ...
#  list(['rubber', 'case', 'fit', 'poorli', 'kept', 'week', 'couldn', 'bother', 'send', 'threw', 'out'])
#  list(['aw', 'fit', 'everi', 'time', 'try', 'holster', 'start', 'come', 'off', 'veri', 'unhappi', 'thi', 'am', 'activ', 'look', 'case'])
#  list(['the', 'phone', 'fell', 'flat', 'screen', 'ft', 'and', 'got', 'shatter', 'screen', 'cost', 'replac', 'ballis', 'letdown', 'stai', 'awai', 'case'])]

# %% [markdown]
# **Compile the word2vec model and save the model**

# %%
model = Word2Vec(stemmed_tokens, min_count = min_count, size = dim, workers = workers, window = window, sg = sg)
model.save("/content/Cell_Phones_and_Accessories_wordvec.model")

# %%
embedded_matrix=[]
vocab_size=len(model.wv.vocab)
words=list(model.wv.vocab.keys())
print(words)
print(len(words))
d=dict()
for w in words:
  try:
    embedded_matrix.append(model.wv[w])
  except:
    print("Word not found")
embedded_matrix[0]
# Out:
# ['look', 'better', 'person', 'be', 'care', 'drop', 'phone', 'rhineston', 'fall', 'duh', 'more', 'decor', 'case', 'protect', 'fit', 'perfectli', 'secur', 'overal', 'pleas', 'purchas', 'when', 'don', 'want', 'spend', 'lot', 'cash', 'great', 'deal', 'thi', 'shop', 'bui', 'from', 'came', 'time', 'love', 'design', 'actual', 'miss', 'stud', 'notic', 'bit', 'sloppi', 'bow', 'haven', 've', 'far', 'for', 'it', 'gave', 'as', 'gift', 'and', 'thei', 'were', 'okai', 'with', 'just', 'not', 'what', 'expect', 'like', 'cute', 'easili', 'recommend', 'the', 'product', 'exactli', 'pictur', 'nice', 'howev', 'dai', 'later', 'fell', 'apart', 'disappoint', 'qualiti', 'final', 'got', 'todai', 'took', 'forev', 'here', 'pic', 'right', 'wrote', 'review', 'start', 'off', 'packag', 'come', 'glue', 'opinion', 'good', 'coupl', 'if', 'that', 'wouldn', 'anoth', 'thank', 'none', 'jewel', 'fallen', 'glu', 'well', 'frame', 'given', 'happi', 'thing', 'know', 'is', 'carri', 'jean', 'tightli', 'big', 'you', 'worth', 'do', 'item', 'serious', 'cheap', 'heck', 'all', 'didn', 'us', 'lose', 'gem', 'wish', 'monei', 'face', 'pretti', 'some', 'stone', 'normal', 'purs', 'super', 'make', 'pret', 'sparklei', 'yeah', 'hahahahahahh', 'daughter', 'long', 'iphon', 'transact', 'went', 'fast', 'veri', 'broke', 'cheapli', 'made', 'too', 'bad', 'grand', 'she', 'uniqu', 'cover', 'beauti', 'outstand', 'everyon', 'compliment', 'think', 'spent', 'wayi', 'low', 'price', 'problem', 'rough', 'can', 'argu', 'appear', 'except', 'white', 'week', 'stai', 'togeth', 'durabl', 'daili', 'charm', 'charli', 'wai', 'high', 'littl', 'bling', 'place', 'sparkli', 'multipl', 'let', 'anymor', 'cours', 'chose', 'ask', 'on', 'of', 'abl', 'tell', 'femin', 'iv', 'fixabl', 'diamond', 'co', 'cement', 'kinda', 'hard', 'hot', 'femal', 'wear', 'gotten', 'complement', 'two', 'though', 'dad', 'help', 'second', 'crystal', 'soon', 'saw', 'soo', 'breakabl', 'sturdi', 'cuter', 'real', 'life', 'so', 'ar', 'wait', 'get', 'would', 'prissi', 'pink', 'remov', 'ribbon', 'wasi', 'darker', 'show', 'wonki', 'bought', 'mom', 'definit', 'bulki', 're', 'small', 'longer', 'averag', 'arriv', 'perfect', 'condit', 'damag', 'send', 'new', 'replac', 'instantli', 'transform', 'theon', 'bwe', 'color', 'bedazzl', 'ye', 'receiv', 'wa', 'month', 'nope', 'strongli', 'attach', 'amaz', 'doesn', 'impact', 'kind', 'unfortun', 'crazi', 'lifestyl', 'throw', 'bag', 'pocket', 'plastic', 'volum', 'button', 'break', 'but', 'special', 'occas', 'onli', 'my', 'teenag', 'star', 'feel', 'go', 'loos', 'provid', 'no', 'simpli', 'slightli', 'extrem', 'easi', 'describ', 'cell', 'an', 'rene', 'order', 'christma', 'differ', 'everybodi', 'moment', 'open', 'fact', 'earlier', 'soooo', 'complaint', 'text', 'after', 'awhil', 'peel', 'friend', 'her', 'hirl', 'need', 'hello', 'kitti', 'collect', 'choos', 'amazon', 'last', 'prettier', 'funnier', 'famili', 'member', 'truli', 'girli', 'girl', 'iton', 'bathroom', 'floor', 'crack', 'mine', 'held', 'lost', 'bare', 'simpl', 'brand', 'cone', 'clue', 'stink', 'peopl', 'babi', 'smell', 'loud', 'stick', 'out', 'ship', 'lie', 'extra', 'town', 'especi', 'contact', 'refund', 'free', 'sinc', 'gorgeou', 'paint', 'clear', 'constantli', 'im', 'hesit', 'mind', 'chang', 'cutest', 'which', 'weird', 'caus', 'thought', 'gonna', 'black', 'classi', 'rich', 'buck', 'wrong', 'even', 'stuff', 'tri', 'sooo', 'definatlei', 'plenti', 'fav', 'kept', 'have', 'sum', 'onc', 'ran', 'da', 'lol', 'plan', 'everydai', 'close', 'instead', 'slant', 'angl', 'straight', 'back', 'biggi', 'necessari', 'side', 'sure', 'excess', 'non', 'either', 'definti', 'sever', 'most', 'store', 'believ', 'mark', 'silver', 'reciev', 'dirti', 'background', 'grai', 'um', 'doesnt', 'shini', 'film', 'old', 'snazzi', 'quickli', 'vivid', 'soft', 'rubber', 'excel', 'idea', 'sweet', 'sealant', 'anyth', 'cool', 'effect', 'cost', 'rub', 'other', 'husband', 'evo', 'step', 'present', 'bright', 'meal', 'toi', 'sturdier', 'burst', 'said', 'again', 'readi', 'excit', 'then', 'hand', 'realiz', 'sai', ...
# 28776
# array([ 0.07629935,  0.09934748,  0.28636965,  0.17831433,  0.25044376,
#         0.35616016,  0.07090731,  0.13086367,  0.69161564, -0.48810902,
#         0.07003625, -0.47046646,  0.10394704, -0.24352965,  0.17088366,
#        -0.10113315, -0.13200523, -0.6357845 ,  0.25706202,  0.1679882 ,
#         0.23189239, -0.7486203 ,  0.43152726, -0.02845055,  0.26779088,
#        -0.61599207, -0.44634312,  0.3407318 , -0.30198586, -0.10325061,
#        -0.205022  ,  0.05525421,  0.251885  , -0.03910535,  0.31874308,
#        -0.00589792, -0.11678181,  0.26002374, -0.26040298, -0.10227366,
#         0.08572169, -0.40318742, -0.19379422,  0.40650144,  0.32528234,
#         0.63823134,  0.32444438, -0.33788395, -0.10238775, -0.00196284,
#         0.1841028 , -0.3237222 ,  0.671873  ,  0.3571726 ,  0.22026415,
#        -0.5936914 ,  0.24824527, -0.14264612, -0.237571  ,  0.1981395 ,
#         0.05217509, -0.32795203,  0.38160053, -0.22402821,  0.30432406,
#         0.12767722, -0.25059065,  0.3463975 ,  0.1231373 , -0.42858294,
#         0.03732801,  0.5722843 , -0.5013489 ,  0.20882316, -0.20551415,
#         0.44928008, -0.1622373 , -0.126609  , -0.08757887,  0.12496547,
#        -0.13133904,  0.26823783, -0.08446727,  0.39407235, -0.11442772,
#        -0.16224119, -0.18508513, -0.57946265,  0.09934045, -0.29195678,
#         0.03360972,  0.21267253, -0.28636557,  0.04406993, -0.02607437,
#        -0.26245537, -0.42199695,  0.08371659,  0.11086842, -0.50215226],
#       dtype=float32)

# %%
m=len(stemmed_tokens[0])
for i in stemmed_tokens:
  l=len(i)
  if m<l:
    m=l
print(m)
# Out:
# 1870

# %% [markdown]
# **Generate the word embeddings matrix**

# %%
import numpy as np
embeddedmatrix=np.array(model.wv)
embeddedmatrix
# Out:
# array(<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7f95a557da10>,
#       dtype=object)

# %% [markdown]
# **Transform each review to corresponding word vector embeddings**
#
#
#
# **Each review is represented by 100 dimensional vector (Mean of all the word embeddings)**
#
# Write the result to .csv file

# %%
word2vec_filename ='train_review_word2vec_100.csv'
features = (newdf['stemmed'])
labels = newdf['Sentiment']
with open(word2vec_filename, 'w+') as word2vec_file:
    for index, row in features.items():
        model_vector = (np.mean([model[token] for token in row], axis=0)).tolist()
        if index == 0:
            header = ",".join(str(ele) for ele in range(100))
            word2vec_file.write(header)
            word2vec_file.write("\n")
        if type(model_vector) is list:  
            line1 = ",".join( [str(vector_element) for vector_element in model_vector] )
        else:
            line1 = ",".join([str(0) for i in range(100)])
        word2vec_file.write(line1)
        word2vec_file.write('\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# **Store the review embeddings to dataframe**

# %%
from sklearn.tree import DecisionTreeClassifier
word2vec_df = pd.read_csv(word2vec_filename)
word2vec_df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.201102  0.149875 -0.112171  0.118383  0.416979  0.327286  0.154336
# 1      0.351723  0.146811 -0.206192  0.096770  0.406218  0.204849  0.126309
# 2      0.285156  0.148674  0.009843  0.205816  0.458559  0.333724  0.183890
# 3      0.156542  0.214251 -0.047994  0.226156  0.330246  0.323934 -0.128445
# 4      0.106647  0.122458 -0.093243  0.057714  0.415199  0.330782  0.282219
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  0.275240  0.268842 -0.105282  0.047685  0.422296  0.329610  0.170659
# 99996  0.226305  0.234817 -0.144354  0.016274  0.400869  0.230626  0.053952
# 99997  0.222326  0.185661 -0.127061  0.117363  0.423375  0.361657  0.139204
# 99998  0.222889  0.136583 -0.102832  0.101539  0.447973  0.309816  0.045750
# 99999  0.123813  0.147630 -0.142090  0.072478  0.544649  0.352158  0.074812
#
#               7         8         9  ...        90        91        92  \
# 0      0.057478  0.447208 -0.186070  ... -0.268290  0.299024 -0.344833
# 1      0.055647  0.284582 -0.273914  ... -0.351445  0.269002 -0.331432
# 2      0.081429  0.298612 -0.071473  ... -0.163430  0.249583 -0.244086
# 3      0.082838  0.350057 -0.189285  ... -0.273811  0.173252 -0.326897
# 4      0.032486  0.366546 -0.092426  ... -0.294113  0.292388 -0.442882
# ...         ...       ...       ...  ...       ...       ...       ...
# 99995 -0.101163  0.300907 -0.190797  ... -0.352807  0.447245 -0.294171
# 99996  0.067196  0.307234 -0.211814  ... -0.306989  0.308030 -0.233209
# 99997  0.067513  0.292826 -0.089660  ... -0.305266  0.403562 -0.341631
# 99998  0.009233  0.464476 -0.156971  ... -0.156217  0.250843 -0.218813
# 99999  0.154412  0.308005 -0.098724  ... -0.306696  0.301452 -0.233618
#
#              93        94        95        96        97        98        99
# 0     -0.173966 -0.181065 -0.201993 -0.118203  0.078211  0.175062 -0.164593
# 1     -0.125766 -0.346509 -0.236837 -0.077785 -0.038711  0.112401 -0.158287
# 2      0.010536 -0.212766 -0.142644 -0.139323  0.166398  0.321142 -0.183039
# 3     -0.139023 -0.384983 -0.139406 -0.159024  0.013196  0.300179 -0.248503
# 4     -0.188807 -0.232056 -0.154678 -0.242584  0.122429  0.257907 -0.282877
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995 -0.294370 -0.192227 -0.030138 -0.216543  0.132777  0.371935  0.049680
# 99996 -0.063928 -0.393219 -0.210882 -0.077741  0.028259  0.200243 -0.133496
# 99997 -0.098265 -0.487246 -0.177771 -0.145369  0.198640  0.294211 -0.012900
# 99998 -0.198054 -0.258687 -0.177395 -0.140799  0.136471  0.135503 -0.096089
# 99999 -0.065453 -0.174946 -0.184236 -0.107279  0.152028  0.325801 -0.140818
#
# [100000 rows x 100 columns]

# %% [markdown]
# **Decision Tree Classifier**

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
clf_decision_word2vec = DecisionTreeClassifier()
features = word2vec_df
labels = newdf['Sentiment']
clf_decision_word2vec.fit(features,labels)
# Out:
# DecisionTreeClassifier()

# %%
testreviews = []
testsentiment = []
t_p=0
t_ng=0
t_emp=0
with gzip.open('/content/Electronics.json.gz') as f:
    for l in f:
      if t_p==5000 and t_ng==5000:
        break
      t_d=json.loads(l.strip())
      t_r=t_d.get("reviewText","")
      if t_r=="":
        t_emp+=1
        continue
      t_rating=int(t_d.get('overall'))
      if t_rating>=3 and t_p<5000:
        testsentiment.append(1)
        testreviews.append(t_r)
        t_p+=1
      elif t_rating<3 and t_ng<5000:
        testsentiment.append(0)
        testreviews.append(t_r)
        t_ng+=1

print(t_emp)
testset={'treview':testreviews,'tsentiment':testsentiment}
tdf=pd.DataFrame(testset)
tdf['tsentiment'].describe()
# Out:
# 7
# count    10000.000000
# mean         0.500000
# std          0.500025
# min          0.000000
# 25%          0.000000
# 50%          0.500000
# 75%          1.000000
# max          1.000000
# Name: tsentiment, dtype: float64

# %%
tdf.head()
# Out:
#                                              treview  tsentiment
# 0  This was the first time I read Garcia-Aguilera...           1
# 1  As with all of Ms. Garcia-Aguilera's books, I ...           1
# 2  I've not read any of Ms Aguilera's works befor...           1
# 3  This romance novel is right up there with the ...           1
# 4  Carolina Garcia Aguilera has done it again.  S...           1

# %%
newtestreviews=[]
for line in testreviews:
  newtestreviews.append(remove_stopwords(line))
newtestreviews[:10]

testset={'treview':newtestreviews,'tsentiment':testsentiment}
newtestdf=pd.DataFrame(testset)
newtestdf.head()
# Out:
#                                              treview  tsentiment
# 0  This time I read Garcia-Aguilera. I came book ...           1
# 1  As Ms. Garcia-Aguilera's books, I think MUST R...           1
# 2  I've read Ms Aguilera's works before, having f...           1
# 3  This romance novel right rest amazing mystery ...           1
# 4  Carolina Garcia Aguilera again. She's written ...           1

# %%
newtestdf['tokenized']=newtestdf['treview'].apply(simple_preprocess,deacc=True)
newtestdf.head()
# Out:
#                                              treview  tsentiment  \
# 0  This time I read Garcia-Aguilera. I came book ...           1
# 1  As Ms. Garcia-Aguilera's books, I think MUST R...           1
# 2  I've read Ms Aguilera's works before, having f...           1
# 3  This romance novel right rest amazing mystery ...           1
# 4  Carolina Garcia Aguilera again. She's written ...           1
#
#                                            tokenized
# 0  [this, time, read, garcia, aguilera, came, boo...
# 1  [as, ms, garcia, aguilera, books, think, must,...
# 2  [ve, read, ms, aguilera, works, before, having...
# 3  [this, romance, novel, right, rest, amazing, m...
# 4  [carolina, garcia, aguilera, again, she, writt...

# %%
porter_stemmer = PorterStemmer()
newtestdf['stemmed']=[[porter_stemmer.stem(word) for word in tokens] for tokens in newtestdf['tokenized'] ]
newtestdf.head()
# Out:
#                                              treview  tsentiment  \
# 0  This time I read Garcia-Aguilera. I came book ...           1
# 1  As Ms. Garcia-Aguilera's books, I think MUST R...           1
# 2  I've read Ms Aguilera's works before, having f...           1
# 3  This romance novel right rest amazing mystery ...           1
# 4  Carolina Garcia Aguilera again. She's written ...           1
#
#                                            tokenized  \
# 0  [this, time, read, garcia, aguilera, came, boo...
# 1  [as, ms, garcia, aguilera, books, think, must,...
# 2  [ve, read, ms, aguilera, works, before, having...
# 3  [this, romance, novel, right, rest, amazing, m...
# 4  [carolina, garcia, aguilera, again, she, writt...
#
#                                              stemmed
# 0  [thi, time, read, garcia, aguilera, came, book...
# 1  [as, ms, garcia, aguilera, book, think, must, ...
# 2  [ve, read, ms, aguilera, work, befor, have, fi...
# 3  [thi, romanc, novel, right, rest, amaz, myster...
# 4  [carolina, garcia, aguilera, again, she, writt...

# %%
newtestdf['stemmed'].head()
# Out:
# 0    [thi, time, read, garcia, aguilera, came, book...
# 1    [as, ms, garcia, aguilera, book, think, must, ...
# 2    [ve, read, ms, aguilera, work, befor, have, fi...
# 3    [thi, romanc, novel, right, rest, amaz, myster...
# 4    [carolina, garcia, aguilera, again, she, writt...
# Name: stemmed, dtype: object

# %%
newtestdf=newtestdf.drop(columns=["treview","tokenized"],axis=1)
newtestdf.head()
# Out:
#    tsentiment                                            stemmed
# 0           1  [thi, time, read, garcia, aguilera, came, book...
# 1           1  [as, ms, garcia, aguilera, book, think, must, ...
# 2           1  [ve, read, ms, aguilera, work, befor, have, fi...
# 3           1  [thi, romanc, novel, right, rest, amaz, myster...
# 4           1  [carolina, garcia, aguilera, again, she, writt...

# %%
dim = 100
window = 3
min_count = 1
workers = 4 #threads
sg = 1 # skip gram model =1
test_stemmed_tokens = pd.Series(newtestdf['stemmed']).values
print(test_stemmed_tokens)
# Out:
# [list(['thi', 'time', 'read', 'garcia', 'aguilera', 'came', 'book', 'live', 'regi', 'kelli', 'thi', 'book', 'exactli', 'look', 'hit', 'spot', 'enjoi', 'book', 'written', 'onc', 'start', 'book', 'kept', 'come', 'more', 'it', 'cultur', 'famili', 'friendship', 'romanc', 'look', 'littl', 'romanc', 'pick', 'book', 'end', 'turn', 'right', 'love', 'main', 'chartacht', 'margarita', 'aka', 'daisi', 've', 'miami', 'wai', 'daisi', 'told', 'stori', 'certainli', 'felt', 'there', 'also', 'go', 'daisi', 'peril', 'close', 'book', 'feel', 'grown', 'emotion', 'well'])
#  list(['as', 'ms', 'garcia', 'aguilera', 'book', 'think', 'must', 'read', 'imposs', 'down', 'success', 'deviat', 'past', 'lupe', 'solano', 'seri', 'captur', 'essenc', 'excit', 'local', 'color', 'divers', 'fabric', 'miami', 'sensual', 'cultur', 'enlighten'])
#  list(['ve', 'read', 'ms', 'aguilera', 'work', 'befor', 'have', 'finish', 'on', 'hot', 'summer', 'go', 'check', 'lupe', 'solano', 'seri', 've', 'heard', 'about', 'on', 'hot', 'summer', 'sooo', 'steami', 'made', 'want', 'miami', 'couldn', 'book', 'down'])
#  ...
#  list(['reciev', 'fisher', 'slim', 'thing', 'notic', 'plastici', 'product', 'overal', 'weakli', 'worri', 'turn', 'volum', 'dial', 'fast', 'fact', 'come', 'loos', 'if', 'look', 'decent', 'qualiti', 'sound', 'steer', 'clear', 'audio', 'qualiti', 'desir', 'take', 'consider', 'slim', 'design', 'sure', 'definatli', 'improv', 'apon'])
#  list(['what', 'disappoint', 'thi', 'look', 'great', 'desk', 'sound', 'perform', 'horribl', 'exagger', 'the', 'volum', 'knob', 'extrem', 'fickl', 'inconsist', 'work', 'want', 'to', 'speaker', 'distort', 'minimum', 'volum', 'open', 'box', 'set', 'up', 'pop', 'cd', 'sooner', 'box', 'readi', 'ship', 'back', 'sorri', 'fisher', 'it', 'person', 'go', 'strictli', 'look', 'good', 'product'])
#  list(['intrigu', 'design', 'store', 'bought', 'sound', 'nice', 'got', 'home', 'took', 'out', 'dissapoint', 'sound', 'qualiti', 'sound', 'good', 'low', 'volum', 'turn', 'get', 'distort', 'speaker', 'much', 'at', 'there', 'notic', 'squeak', 'cd', 'plai', 'thankfulli', 'went', 'awai', 'if', 'look', 'look', 'get', 'perform', 'wise', 'don', 'think', 'so'])]

# %%
testmodel = Word2Vec(test_stemmed_tokens, min_count = min_count, size = dim, workers = workers, window = window, sg = sg)
testmodel.save("/content/electronics10000.model")

# %%
word2vec_filename ='test_review_word2vec_electronics.csv'
testfeatures = (newtestdf['stemmed'])
testlabels = newtestdf['tsentiment']
with open(word2vec_filename, 'w+') as word2vec_file:
    for index, row in testfeatures.items():
      model_vector = (np.mean([testmodel[token] for token in row], axis=0)).tolist()
      if index == 0:
          header = ",".join(str(ele) for ele in range(100))
          word2vec_file.write(header)
          word2vec_file.write("\n")
      if type(model_vector) is list:  
          line1 = ",".join( [str(vector_element) for vector_element in model_vector] )
      else:
          line1 = ",".join([str(0) for i in range(100)])
      word2vec_file.write(line1)
      word2vec_file.write('\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
test_df = pd.read_csv(word2vec_filename)
test_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.101114  0.187956  0.112255  0.173764  0.329515 -0.091193  0.017521
# 1     0.026571  0.181777  0.112661  0.160100  0.259524 -0.071283 -0.012348
# 2     0.126531  0.207412  0.064850  0.147857  0.347451 -0.062478  0.013363
# 3     0.107136  0.197011  0.117682  0.184625  0.332852 -0.117511 -0.000217
# 4     0.053885  0.136751  0.107622  0.178785  0.302442 -0.090097  0.017779
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.074040  0.302943  0.098401  0.216110  0.383185 -0.071323 -0.025246
# 9996  0.107955  0.242960  0.042789  0.166086  0.364952  0.048111 -0.032899
# 9997  0.099178  0.258980  0.042428  0.157956  0.327532  0.018058 -0.074173
# 9998  0.128668  0.271356  0.055805  0.168621  0.384702  0.039111 -0.042001
# 9999  0.153560  0.215504  0.060668  0.212662  0.387500 -0.008747 -0.033432
#
#              7         8         9  ...        90        91        92  \
# 0     0.075244  0.195732 -0.103139  ... -0.169747 -0.003647 -0.113560
# 1     0.072837  0.215870 -0.113231  ... -0.124038  0.021418 -0.084178
# 2     0.132603  0.212351 -0.099188  ... -0.181747  0.000802 -0.115498
# 3     0.054227  0.199995 -0.124115  ... -0.165153 -0.007770 -0.074437
# 4     0.067449  0.195120 -0.157921  ... -0.178129  0.009265 -0.124857
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.131392  0.250428 -0.062728  ... -0.076838  0.032918 -0.131642
# 9996  0.075454  0.220500 -0.120591  ... -0.149167  0.058439 -0.108760
# 9997  0.018857  0.196663 -0.068405  ... -0.162155 -0.011379 -0.114924
# 9998  0.100323  0.229990 -0.123674  ... -0.155902  0.035042 -0.135866
# 9999  0.113817  0.242014 -0.109667  ... -0.183355 -0.019021 -0.141708
#
#             93        94        95        96        97        98        99
# 0    -0.178687 -0.143147 -0.007474 -0.032628  0.132370  0.293125 -0.395657
# 1    -0.109378 -0.130558  0.006736 -0.050064  0.069358  0.267093 -0.354992
# 2    -0.189689 -0.124184 -0.020767  0.004547  0.036262  0.268855 -0.401255
# 3    -0.186986 -0.174308  0.027719 -0.060444  0.101355  0.299018 -0.451777
# 4    -0.162127 -0.146592 -0.012956 -0.040450  0.114863  0.268735 -0.373408
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.205731 -0.104652 -0.050079 -0.028155  0.208551  0.347064 -0.445989
# 9996 -0.235277 -0.049310 -0.037583  0.083080  0.161348  0.267207 -0.416793
# 9997 -0.269588 -0.006341 -0.039465  0.044309  0.232953  0.290361 -0.401188
# 9998 -0.254373 -0.048874 -0.068895  0.057688  0.169285  0.286728 -0.423430
# 9999 -0.276402 -0.059910 -0.045448  0.072612  0.205925  0.306551 -0.439747
#
# [10000 rows x 100 columns]

# %%
from sklearn.metrics import classification_report
test_predictions_word2vec = clf_decision_word2vec.predict(test_df)
print(classification_report(newtestdf['tsentiment'].values,test_predictions_word2vec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.88      0.67      5000
#            1       0.68      0.26      0.38      5000
#
#     accuracy                           0.57     10000
#    macro avg       0.61      0.57      0.52     10000
# weighted avg       0.61      0.57      0.52     10000

# %%
newtestdf['predicted']=test_predictions_word2vec

# %%
newtestdf
# Out:
#       tsentiment                                            stemmed  predicted
# 0              1  [thi, time, read, garcia, aguilera, came, book...          1
# 1              1  [as, ms, garcia, aguilera, book, think, must, ...          0
# 2              1  [ve, read, ms, aguilera, work, befor, have, fi...          0
# 3              1  [thi, romanc, novel, right, rest, amaz, myster...          1
# 4              1  [carolina, garcia, aguilera, again, she, writt...          0
# ...          ...                                                ...        ...
# 9995           0  [look, great, control, imposs, master, thei, i...          0
# 9996           0  [consid, radio, come, box, mark, execut, micro...          1
# 9997           0  [reciev, fisher, slim, thing, notic, plastici,...          1
# 9998           0  [what, disappoint, thi, look, great, desk, sou...          0
# 9999           0  [intrigu, design, store, bought, sound, nice, ...          0
#
# [10000 rows x 3 columns]

# %%
from sklearn import svm

# %%
svm_clf=svm.SVC()
svm_clf.fit(features,labels)
# Out:
# SVC()

# %%
test_predictions_word2vec = svm_clf.predict(test_df)
print(classification_report(newtestdf['tsentiment'].values,test_predictions_word2vec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.23      0.33      5000
#            1       0.52      0.85      0.65      5000
#
#     accuracy                           0.54     10000
#    macro avg       0.56      0.54      0.49     10000
# weighted avg       0.56      0.54      0.49     10000

# %%
newtestdf
# Out:
#       tsentiment                                            stemmed  predicted
# 0              1  [thi, time, read, garcia, aguilera, came, book...          1
# 1              1  [as, ms, garcia, aguilera, book, think, must, ...          0
# 2              1  [ve, read, ms, aguilera, work, befor, have, fi...          0
# 3              1  [thi, romanc, novel, right, rest, amaz, myster...          1
# 4              1  [carolina, garcia, aguilera, again, she, writt...          0
# ...          ...                                                ...        ...
# 9995           0  [look, great, control, imposs, master, thei, i...          0
# 9996           0  [consid, radio, come, box, mark, execut, micro...          1
# 9997           0  [reciev, fisher, slim, thing, notic, plastici,...          1
# 9998           0  [what, disappoint, thi, look, great, desk, sou...          0
# 9999           0  [intrigu, design, store, bought, sound, nice, ...          0
#
# [10000 rows x 3 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rfmodel = RandomForestClassifier(n_estimators = 100)
rfmodel.fit(features,labels)
# Out:
# RandomForestClassifier()

# %%
test_predictions_word2vec = rfmodel.predict(test_df)
print(classification_report(newtestdf['tsentiment'].values,test_predictions_word2vec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.94      0.69      5000
#            1       0.78      0.19      0.31      5000
#
#     accuracy                           0.57     10000
#    macro avg       0.66      0.57      0.50     10000
# weighted avg       0.66      0.57      0.50     10000

# %%
from sklearn.linear_model import LogisticRegression
lrmodel = LogisticRegression(max_iter=1000)
lrmodel.fit(features,labels)
# Out:
# LogisticRegression(max_iter=1000)

# %%
test_predictions_word2vec = lrmodel.predict(test_df)
print(classification_report(newtestdf['tsentiment'].values,test_predictions_word2vec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.03      0.05      5000
#            1       0.51      0.99      0.67      5000
#
#     accuracy                           0.51     10000
#    macro avg       0.66      0.51      0.36     10000
# weighted avg       0.66      0.51      0.36     10000
